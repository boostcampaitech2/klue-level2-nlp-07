# %%
import pandas as pd
import numpy as np
import re
import pickle

from transformers import AutoTokenizer
from load_data import *

from koeda import EDA, AEDA

# %% [markdown]
# ## 숫자 사이 콤마를 어떻게 처리할 것인가

# %%
MODEL_NAME = 'klue/roberta-large'
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
data = load_data("../dataset/train/train.csv")
data.sample(10)
# Out:
#           id                                           sentence  \
# 25768  25768  법정 통화는 뉴질랜드 달러와 쿡 제도 달러로 2종류이나, 국내에서 유통되는 경제통화...
# 9335    9335  1933년 국가사회주의 독일 노동자당(나치당)이 독일의 권력을 잡음으로써(마흐터그라...
# 14848  14848  먼저 청의 외교부 협조를 받아, 당시 이홍장 휘하의 조선 주재 청국 공사 원세개(위...
# 11710  11710  리옹 합류와 함께, 에시엔은 등번호 4번을 받고 광역 미드필더로 활약했는데, 그는 ...
# 18290  18290  리버풀은 31일(한국시간) 영국 리버풀의 안필드에서 열린 2019-2020 카라바오...
# 31160  31160  제63대 법무부 장관과 제44대 국무총리를 역임하였고, 2020년 2월 17일부터 ...
# 12502  12502  광주광역시서부교육지원청이 주최한 공간 혁신의 일환으로 진행된 휴마루 사업을 통하여 ...
# 14528  14528  2008년 10월 2일 최진실의 죽음과 관련해 국민들은 "씩씩하게 잘 살아왔는데 왜...
# 26872  26872   광복 직후에는 조만식의 조선민주당에 참가했으나 반공 인사였기에 소군정과 마찰을 빚었다.
# 19258  19258  프란체스코 마리아 1세 델라 로베레(1490년 3월 22일 - 1538년 10월 2...
#
#               subject_entity   object_entity                label
# 25768                 '쿡 제도'          '뉴질랜드'          no_relation
# 9335                   '나치당'       '독일 노동자당'  org:alternate_names
# 14848                  '원세개'           '이홍장'          no_relation
# 11710                  '에시엔'          '미드필더'          no_relation
# 18290              '디보크 오리기'           '리버풀'      per:employee_of
# 31160                '미래통합당'  '2020년 2월 17일'          no_relation
# 12502                '송광중학교'  '광주광역시서부교육지원청'          no_relation
# 14528                  '최진실'  '2008년 10월 2일'    per:date_of_death
# 26872                  '조만식'         '조선민주당'      per:employee_of
# 19258  '프란체스코 마리아 1세 델라 로베레'       '우르비노 공작'            per:title

# %%
data[data.subject_entity=="'신라대학교'"]
# Out:
#           id                                           sentence  \
# 3024    3024  신라대학교 도서관은 당초 부산여자대숙 숙장이었던 박해곤 숙장(현 박영학원 이사)이 ...
# 17331  17331  신라대학교는 재단법인인 박영학원이 1954년 부산여자대숙을 설립한 데 이어 1964...
# 19457  19457  신라대학교 도서관은 당초 부산여자대숙 숙장이었던 박해곤 숙장(현 박영학원 이사)이 ...
# 19942  19942  신라대학교는 일제강점기 부산 지역에서 부산면포합자회사, 부산대동연료공업사, 부산정미...
#
#       subject_entity object_entity           label
# 3024         '신라대학교'        '박영학원'     no_relation
# 17331        '신라대학교'        '박영학원'   org:member_of
# 19457        '신라대학교'         '박해곤'     no_relation
# 19942        '신라대학교'         '박영택'  org:founded_by

# %%
data[data.subject_entity=="'스페인'"]
# Out:
#           id                                           sentence  \
# 440      440  21세의 앙갱 공작 루이가 지휘하는 프랑스군은 재빠르게 스페인 군의 움직임에 반응하...
# 6350    6350  이 작품은 스페인 국왕 펠리페 4세의 마드리드 궁전에 있는 큰 방을 그린 것이며, ...
# 13313  13313  얼마 뒤 아브드 엘 크림은 아누알(Annual)의 스페인 보병대를 급습하여 단 30...
# 13502  13502  마드리드 또는 발렌시아가 스페인 후보일 것이라는 소문이 있었으나, 스페인은 끝내 바...
# 19663  19663  약 27000명에 달하는 합스부르크 가문의 스페인-신성로마제국 연합군은 아르덴(Ar...
# 20436  20436  바이에른 뮌헨의 감독으로 부임한 이후에도 분데스리가 3연패를 달성하면서 바르셀로나에...
# 21811  21811  디에고 다 실바 코스타 또는 지에구 다 시우바 코스타는 브라질 출신 스페인 축구 선...
# 21821  21821  얼마 뒤 아브드 엘 크림은 아누알(Annual)의 스페인 보병대를 급습하여 단 30...
# 24447  24447  이 경기 승리로 레알 마드리드는 스페인 리그 역사상 최초로 단일 시즌 승점 100점...
# 25703  25703  그는 등번호 14번을 부여 받았고, 마드리드에서 열린 1-2로 패배한 스페인과의 친...
# 28953  28953  스페인군은 사상자, 포로를 합쳐 15000명의 피해를 입었으며, 프랑스군은 약 40...
# 30313  30313  클라시크라는 단어는 스페인 라 리가의 레알 마드리드 CF와 FC 바르셀로나간의 더비...
# 31091  31091  그런데 마드리드 조약에서 스페인과 포르투갈이 우루과이강을 국경으로 삼기로 하고 우루...
# 31272  31272  2015년 1월 22일, 스페인 라 리가의 레알 마드리드가 비공개 금액에 시우바를 ...
# 32406  32406  충북경자청과 코트라 마드리드 무역관이 공동 주최하고 스페인 제약협회(Farma In...
#
#       subject_entity object_entity                      label
# 440            '스페인'       '6000명'                no_relation
# 6350           '스페인'        '마드리드'                no_relation
# 13313          '스페인'       '8000명'                no_relation
# 13502          '스페인'        '마드리드'                org:members
# 19663          '스페인'      '27000명'                no_relation
# 20436          '스페인'        '마드리드'  org:place_of_headquarters
# 21811          '스페인'        '마드리드'  org:place_of_headquarters
# 21821          '스페인'       '3000명'                no_relation
# 24447          '스페인'        '마드리드'                no_relation
# 25703          '스페인'        '마드리드'                org:members
# 28953          '스페인'      '15000명'                no_relation
# 30313          '스페인'        '마드리드'                no_relation
# 31091          '스페인'        '마드리드'                no_relation
# 31272          '스페인'        '마드리드'  org:place_of_headquarters
# 32406          '스페인'        '마드리드'                no_relation

# %%
# 이걸 함수화해서 load_data.py에 반영해야됨
# 숫자 사이에 있는 콤마(,)에서 콤마 지우는 방법
data['sentence'] = data['sentence'].apply(lambda x: re.sub(r'(\d+),(\d+)', r'\1\2', x))
data['subject_entity'] = data['subject_entity'].apply(lambda x: re.sub(r'(\d+),(\d+)', r'\1\2', x))
data['object_entity'] = data['object_entity'].apply(lambda x: re.sub(r'(\d+),(\d+)', r'\1\2', x))
data[data.subject_entity=="'스페인'"]
# Out:
#           id                                           sentence  \
# 440      440  21세의 앙갱 공작 루이가 지휘하는 프랑스군은 재빠르게 스페인 군의 움직임에 반응하...
# 6350    6350  이 작품은 스페인 국왕 펠리페 4세의 마드리드 궁전에 있는 큰 방을 그린 것이며, ...
# 13313  13313  얼마 뒤 아브드 엘 크림은 아누알(Annual)의 스페인 보병대를 급습하여 단 30...
# 13502  13502  마드리드 또는 발렌시아가 스페인 후보일 것이라는 소문이 있었으나, 스페인은 끝내 바...
# 19663  19663  약 27000명에 달하는 합스부르크 가문의 스페인-신성로마제국 연합군은 아르덴(Ar...
# 20436  20436  바이에른 뮌헨의 감독으로 부임한 이후에도 분데스리가 3연패를 달성하면서 바르셀로나에...
# 21811  21811  디에고 다 실바 코스타 또는 지에구 다 시우바 코스타는 브라질 출신 스페인 축구 선...
# 21821  21821  얼마 뒤 아브드 엘 크림은 아누알(Annual)의 스페인 보병대를 급습하여 단 30...
# 24447  24447  이 경기 승리로 레알 마드리드는 스페인 리그 역사상 최초로 단일 시즌 승점 100점...
# 25703  25703  그는 등번호 14번을 부여 받았고, 마드리드에서 열린 1-2로 패배한 스페인과의 친...
# 28953  28953  스페인군은 사상자, 포로를 합쳐 15000명의 피해를 입었으며, 프랑스군은 약 40...
# 30313  30313  클라시크라는 단어는 스페인 라 리가의 레알 마드리드 CF와 FC 바르셀로나간의 더비...
# 31091  31091  그런데 마드리드 조약에서 스페인과 포르투갈이 우루과이강을 국경으로 삼기로 하고 우루...
# 31272  31272  2015년 1월 22일, 스페인 라 리가의 레알 마드리드가 비공개 금액에 시우바를 ...
# 32406  32406  충북경자청과 코트라 마드리드 무역관이 공동 주최하고 스페인 제약협회(Farma In...
#
#       subject_entity object_entity                      label
# 440            '스페인'       '6000명'                no_relation
# 6350           '스페인'        '마드리드'                no_relation
# 13313          '스페인'       '8000명'                no_relation
# 13502          '스페인'        '마드리드'                org:members
# 19663          '스페인'      '27000명'                no_relation
# 20436          '스페인'        '마드리드'  org:place_of_headquarters
# 21811          '스페인'        '마드리드'  org:place_of_headquarters
# 21821          '스페인'       '3000명'                no_relation
# 24447          '스페인'        '마드리드'                no_relation
# 25703          '스페인'        '마드리드'                org:members
# 28953          '스페인'      '15000명'                no_relation
# 30313          '스페인'        '마드리드'                no_relation
# 31091          '스페인'        '마드리드'                no_relation
# 31272          '스페인'        '마드리드'  org:place_of_headquarters
# 32406          '스페인'        '마드리드'                no_relation

# %%
print(tokenizer.decode(tokenizer.encode('6000년')))
print(tokenizer.encode('6000년'))
print(tokenizer.decode(tokenizer.encode('6,000년')))
print(tokenizer.encode('6,000년'))
# Out:
# [CLS] 6000년 [SEP]
# [0, 6891, 2440, 2]
# [CLS] 6, 000년 [SEP]
# [0, 26, 16, 5058, 2440, 2]

# %% [markdown]
# ## EDA, AEDA를 적용한 문장을 새로운 데이터프레임으로 만들기

# %%
INPUT_SENT = data['sentence'][14]
tokenizer.decode(tokenizer.encode(INPUT_SENT))
# Out:
# '[CLS] 조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노, 미켈란젤로, 라파엘로, 보티첼리, 레오나르도 다빈치, 티치아노 등으로 대표되는 이탈리아 르네상스 회화는 당대와 그 이후의 시기 유럽 전체에 영향을 주었다. [SEP]'

# %%
# 13781, 222, 8473(entity 포함), 
NUM = 13781
INPUT_SENT = data['sentence'][NUM]
print(INPUT_SENT)
print(tokenizer.decode(tokenizer.encode(INPUT_SENT)))
print(data['subject_entity'][NUM], data['object_entity'][NUM])
# Out:
# 조소카베 모토치카(ちょうそかべ もとちか), 덴분 8년(1539년) ~ 게이초 4년(1599년 5월 19일))는 조소카베 가문의 제20대 당주이다. 도사(土佐 의 센고쿠 다이묘.
# [CLS] 조소카베 모토치카 ( [UNK] [UNK] ), 덴분 8년 ( 1539년 ) ~ 게이초 4년 ( 1599년 5월 19일 ) ) 는 조소카베 가문의 제20대 당주이다. 도사 ( 土 [UNK] 의 센고쿠 다이묘. [SEP]
# '조소카베 모토치카' '덴분 8년(1539년)'

# %%
input_sent = "조소카베 모토치카(ちょうそかべ もとちか), 덴분 8년(1539년) ~ 게이초 4년(1599년 5월 19일))는 조소카베 가문의 제20대 당주이다. 도사(土佐 의 센고쿠 다이묘."
output_sent = tokenizer.decode(tokenizer.encode(INPUT_SENT), skip_special_tokens=True)
output_sent
# Out:
# '조소카베 모토치카 ( ), 덴분 8년 ( 1539년 ) ~ 게이초 4년 ( 1599년 5월 19일 ) ) 는 조소카베 가문의 제20대 당주이다. 도사 ( 土 의 센고쿠 다이묘.'

# %%
eda = EDA(morpheme_analyzer="Mecab", alpha_sr=0.3, alpha_ri=0.1, alpha_rs=0, prob_rd=0)
result = eda(input_sent)
result
# Out:
# '조소카베 모토치카(ちょうそかべ もとちか), 덴분 8년(1539년) ~ 게이초 4년(1599년 5월 19일))는 조소카베 가문의 제20대 당주이다. 도사(土佐 의 센고쿠 다이묘.'

# %%
INPUT_SENT = data['sentence'][3218]
eda = EDA(morpheme_analyzer="Mecab", alpha_sr=-0.8, alpha_ri=0, alpha_rs=0, prob_rd=0)
result = eda(INPUT_SENT)
print(INPUT_SENT)
print(result)
data.object_entity[440], data.subject_entity[440]
# Out:
# 라마굽타는 사무드라굽타와 찬드라굽타 2세 사이의 공백기인 375년부터 380년까지 굽타 제국을 다스렸다고 추정되는 마하라자디라자이다.
# 라마굽타는 업무드라굽타와 찬드라굽타 2세 사이의 공백기인 375년부터 380년까지 굽타 제국을 다스렸다고 추정되는 마하라자디라자이다.
# ("'6000명'", "'스페인'")

# %%
aeda = AEDA(morpheme_analyzer="Mecab", punc_ratio=0.01, punctuations=["?", "!", ".", ","])
result = aeda(INPUT_SENT)
print(INPUT_SENT)
print(result)
# Out:
# 21세의 앙갱 공작 루이가 지휘하는 프랑스군은 재빠르게 스페인 군의 움직임에 반응하여 6000명에 달하는 스페인 원군이 도착하기 전에 전투를 벌이려 하였다.
# 21세의 앙갱 공작 루이가 지휘하는 프랑스군은 재빠르게 스페인 군의 움직임에 반응하여 6000명에 ? 달하는 스페인 원군이 도착하기 전에 전투를 벌이려 하였다.

# %%
eda = EDA(morpheme_analyzer="Mecab", alpha_sr=-0.8, alpha_ri=0, alpha_rs=0, prob_rd=0)
aeda = AEDA(morpheme_analyzer="Mecab", punc_ratio=0.2, punctuations=["?", "!", ".", ",", "또한", "##"])

def right_augment(en1, en2, text):
    if en1 not in text or en2 not in text:
        return False
    return True

def augment_sent(df, my_eda, my_aeda):
    sentences = list(df['sentence'])
    entities1, entities2 = list(df['object_entity']), list(df['subject_entity'])
    aug_sentences = []
    for i, sent in enumerate(sentences):
        aug_sent = aeda(sent)
        ent1, ent2 = entities1[i], entities2[i]
        if not right_augment(ent1, ent2, aug_sent):
            aug_sent = sent
        aug_sentences.append(aug_sent)
    df['sentence'] = aug_sentences
    return df

# %%
sample_df = data.sample(100)
aug_df = augment_sent(sample_df, eda, aeda)

# %%
len(aug_df)
# Out:
# 100

# %%
aug_df.sample(10)
# Out:
#           id                                           sentence  \
# 7640    7640  영암군(군수 전동평)은 3월부터 2020년 상수원 관리지역 주민지원사업으로 마을 공...
# 23708  23708  스포츠경향에 따르면 간미연 씨와 황바울 씨는 오랫동안 좋은 친구로 알고지내다 3년 ...
# 31367  31367  나주시(시장 강인규)는 동절기를 맞아 오는 26일부터 3일 간 관내 다중이용시설을 ...
# 19762  19762  이스라엘은 레이저 요격은 개발을 중단하고, 아이언 돔으로 헤즈볼라나 하마스 등의 장...
# 29715  29715  김포반도 전투는 한국 전쟁 발발 초기인 1950년 6월 25일에 백선엽 대령이 이끄...
# 7009    7009  지난 2011년부터 달콤커피는 매월 ‘이 달의 아티스트’를 선정, 전국 매장에서 펼...
# 29002  29002  한국에서는 조양호 전 한진그룹 회장을 필두로 한 한진 일가, 유일한 유한양행 창립자...
# 4323    4323     2016년에 데이빈슨 로메로를 대신해 두산 베어스로 영입되어 한국에서 뛰게 되었다.
# 4842    4842  1969-1973년 교육장관, 1973년-1976년 주택장관, 1982년-1986년...
# 12275  12275  GS리테일이 GS25와 랄라블라 등 오프라인 플랫폼을 통합 운영한다고 밝히면서 랄라...
#
#       subject_entity object_entity                      label
# 7640           '영암군'         '전동평'  org:top_members/employees
# 23708          '황바울'         '간미연'                no_relation
# 31367          '나주시'         '강인규'  org:top_members/employees
# 19762         '이스라엘'       '아이언 돔'                no_relation
# 29715         '제1사단'       '한국 전쟁'                no_relation
# 7009          '달콤커피'       '2011년'                no_relation
# 29002          '오뚜기'         '함영준'  org:top_members/employees
# 4323        '두산 베어스'       '2016년'                no_relation
# 4842        '올로프 팔메'         '스웨덴'                 per:origin
# 12275         'GS25'       'GS리테일'              org:member_of
