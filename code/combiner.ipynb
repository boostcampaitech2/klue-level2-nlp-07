# %%
import pandas as pd

# %%
first = "/opt/ml/klue-level2-nlp-07/dataset/train/without_aug.csv"
second = "/opt/ml/klue-level2-nlp-07/dataset/train/aug_aeda.csv"
first_df = pd.read_csv(first)
second_df = pd.read_csv(second)

# %%
combined_df = pd.concat([first_df,second_df],ignore_index=True)
combined_df['id'] = combined_df.index

# %%
combined_df
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 64935  64935  한국 당은 7일 ? 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보...
# 64936  64936  법포 ? 는 다시 최시형, 서 병학, 손병희 직계인 북접과 다시 서장옥, 전봉준 #...
# 64937  64937  완도군 , ( . 군수 . 신우철)이 국토교통부에서 실시한 '2019 교통문화 지수...
# 64938  64938  중앙일보, ## JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들...
# 64939  64939  화순군 ## (군수 구충곤) ! 은 17일 동면의 이장 , 20 ? 여 명이 코로나...
#
#       subject_entity object_entity                      label
# 0              '비틀즈'      '조지 해리슨'                no_relation
# 1            '민주평화당'        '대안신당'                no_relation
# ...

# %%
combined_df.to_csv("/opt/ml/klue-level2-nlp-07/dataset/train/combined.csv",index=False)

# %%
source_add = pd.read_csv("/opt/ml/klue-level2-nlp-07/dataset/train/train.csv")
source =source_add['source']

# %%
first_df['source'] = source

# %%
second_df['source'] = source

# %%
combined_df = pd.concat([first_df,second_df],ignore_index=True)
combined_df['id'] = combined_df.index

# %%
combined_df
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 64935  64935  한국 당은 7일 ? 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보...
# 64936  64936  법포 ? 는 다시 최시형, 서 병학, 손병희 직계인 북접과 다시 서장옥, 전봉준 #...
# 64937  64937  완도군 , ( . 군수 . 신우철)이 국토교통부에서 실시한 '2019 교통문화 지수...
# 64938  64938  중앙일보, ## JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들...
# 64939  64939  화순군 ## (군수 구충곤) ! 은 17일 동면의 이장 , 20 ? 여 명이 코로나...
#
#       subject_entity object_entity                      label     source
# 0              '비틀즈'      '조지 해리슨'                no_relation  wikipedia
# ...
