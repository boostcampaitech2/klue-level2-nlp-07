# %%
import pandas as pd
import random
import seaborn as sns
import pickle

# %%
empty = pd.DataFrame()

pd_dataset = pd.read_csv("../dataset/train/train.csv")

# %%
def data_pruning(dataset):
    dataset = pd.DataFrame(dataset)
    data0 = dataset.loc[dataset['label'] == 'no_relation']
    data1 = dataset.loc[dataset['label'] == 'org:top_members/employees']
    data6 = dataset.loc[dataset['label'] == 'per:employee_of']
    others = dataset.loc[dataset['label'] != 'no_relation']#& dataset['label'] != 'org:top_members/employees' & dataset['label'] != 'per:employee_of']
    
    for id in range(len(data0)):
        prob = random.randint(0,10)
        if prob >= 7:
             data0 = data0.drop(data0[data0.id == id].index)
    dataset = pd.concat([data0,others])
    
    return dataset

# %%
data = data_pruning(pd_dataset)
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 6          6  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...
# 14        14  조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노,...
# 16        16  이정미 대표도 이날 기자회견에 앞서 한 라디오 방송에 출연 "정개특위를 한국당에 내...
# 19        19  이번 포럼은 제주개발공사와 유네스코 아시아-태평양 본부, 한국지질자원연구원이 공동 ...
# ...      ...                                                ...
# 32464  32464  KIA타이거즈 외야수 이창진이 롯데백화점 광주점이 시상하는 9월 월간 MVP에 선정...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 6      {'word': 'AC 밀란', 'start_idx': 64, 'end_idx': ...
# ...

# %%
with open('dict_label_to_num.pkl', 'rb') as f:
    dict_label_to_num = pickle.load(f)
sns.countplot(data = data , x = "whatever")
